# %%
import numpy as np
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, Flatten, Conv2D,Lambda
#from keras.layers import BatchNormalization
from keras_resnet.layers import BatchNormalization
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D,UpSampling2D,Concatenate,Conv2DTranspose,Add
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
#from keras.models import load_model
#import pydot
from keras_retinanet.models import load_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.callbacks import LearningRateScheduler,Callback
from keras.optimizers import RMSprop,SGD
from keras import optimizers
from keras.callbacks import ModelCheckpoint
import glob
import cv2
import os
from math import *
from keras.applications.vgg16 import VGG16 
import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import h5py
from keras.utils import to_categorical
from IPython.display import clear_output
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from keras.preprocessing.image import ImageDataGenerator
from skimage import measure
from imutils import contours
import imutils
import tensorflow as tf
#from keras_retinanet.models.resnet import resnet_retinanet as retinanet, custom_objects, download_imagenet
# %matplotlib inline

# %%
def ODmodel2():
    odmodel = load_model('ResNet-50-model.keras.h5', backbone_name='resnet50')
    #odmodel = VGG16(weights='imagenet', input_shape = (224,224,3),  include_top=False)
    odmodel.layers.pop()
    
    for layer in odmodel.layers:
        layer.trainable = False
    
    
    inputs = odmodel.layers[0].output
    #conv53 = odmodel.layers[17].output
    conv53x = odmodel.layers[151].output
    M5 = Conv2D(256,(1,1),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU')(conv53x)
    conv53 = Conv2D(256,(3,3),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU1')(M5)
    conv5_output = Conv2DTranspose(512,(3,3),padding='same',strides=(2,2),kernel_initializer='he_uniform')(conv53)
    M5_upsample = UpSampling2D(size=(2,2))(M5)
    #conv43 = odmodel.layers[13].output
    conv43x = odmodel.layers[84].output
    conv43_111 = Conv2D(256,(1,1),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU2')(conv43x)
    #conv43_befupsamp = Conv2D(256,(3,3),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU3')(conv43_111)
    #conv4_forupsample = UpSampling2D(size=(2,2))(conv43_111)
    M4 = Add()([M5_upsample,conv43_111])
    conv43 = Conv2D(256,(3,3),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU3')(M4)
    M4_upsample = UpSampling2D(size=(2,2))(M4) 
    
    
    conv33x = odmodel.layers[37].output
    conv33_111 = Conv2D(256,(1,1),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU4')(conv33x)
    M3 = Add()([M4_upsample,conv33_111])
    conv33 = Conv2D(256,(3,3),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU5')(M3)
    M3_upsample = UpSampling2D(size=(2,2))(M3) 
    
    
    conv22x = odmodel.layers[2].output
    conv22_111 = Conv2D(256,(1,1),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU6')(conv22x)
    M2 = Add()([M3_upsample,conv22_111])
    conv22 = Conv2D(256,(3,3),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU7')(M2)
    #M3_upsample = UpSampling2D(size=(2,2))(M3)
    #conv22 = Conv2D(256,(3,3),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='BABLUBABLU7')(conv22_111)
    
    
    
    
    
    
    
    
    
    D11 = Conv2D(256,(3,3),strides=(1,1),padding='same',kernel_initializer = 'he_uniform',name='convD11')(conv43)
    #drop11 = Dropout(0.2)(D11)
    D12 = BatchNormalization(axis = 3,freeze = True, name = 'bnD11')(D11)
    D13 = Activation('relu')(D12)
    D14 = Conv2D(256,(3,3),strides=(1,1),padding='same',kernel_initializer = 'he_uniform',name='convD12')(D13)
    #drop12 = Dropout(0.2)(D14)
    D15 = BatchNormalization(axis = 3, freeze = True,name = 'bnD12')(D14)
    D1_output = Activation('relu')(D15)
    
    #conv33 = odmodel.layers[9].output
    
    D21 = Conv2D(128,(3,3),strides=(1,1),padding='same',kernel_initializer = 'he_uniform',name='convD21')(conv33)
   # drop21 = Dropout(0.2)(D21)
    D22 = BatchNormalization(axis = 3,freeze = True, name = 'bnD21')(D21)
    D23 = Activation('relu')(D22)
    D24 = Conv2D(128,(3,3),strides=(1,1),padding='same',kernel_initializer = 'he_uniform',name='convD22')(D23)
    #drop22 = Dropout(0.2)(D24)
    D25 = BatchNormalization(axis = 3,freeze = True, name = 'bnD22')(D24)
    D2_output = Activation('relu')(D25)

    #conv22 = odmodel.layers[5].output
    
    D31 = Conv2D(64,(3,3),strides=(1,1),padding='same',kernel_initializer = 'he_uniform',name='convD31')(conv22)
   # drop31 = Dropout(0.2)(D31)
    D32 = BatchNormalization(axis = 3,freeze = True, name = 'bnD31')(D31)
    D33 = Activation('relu')(D32)
    D34 = Conv2D(64,(3,3),strides=(1,1),padding='same',kernel_initializer = 'he_uniform',name='convD32')(D33)
    #drop32 = Dropout(0.2)(D34)
    D35 = BatchNormalization(axis = 3,freeze = True, name = 'bnD32')(D34)
    D3_output = Activation('relu')(D35)
    
    decon11 = Concatenate()([D1_output,conv5_output])
    decon12 = Conv2D(256,(3,3),strides=(1,1),padding = 'same',kernel_initializer = 'he_uniform',name='deconv11')(decon11)
    decon13 = BatchNormalization(axis = 3,freeze = True, name = 'bnde11')(decon12)
    decon14 = Activation('relu')(decon13)
    decon15 = Conv2D(256,(3,3),strides=(1,1),padding = 'same',kernel_initializer = 'he_uniform',name='deconv12')(decon14)
    decon16 = BatchNormalization(axis = 3,freeze = True, name = 'bnde12')(decon15)
    decon17 = Activation('relu')(decon16)
    decon1_output = Conv2DTranspose(256,(3,3),padding='same',strides=(2,2),kernel_initializer='he_uniform')(decon17)
    #decon18 = UpSampling2D(size=(2,2))(decon17)
    #decon1_output = Conv2DTranspose(256,(3,3),padding='same',strides=(1,1),kernel_initializer='he_uniform')(decon18)
    
    decon21 = Concatenate()([D2_output,decon1_output])
    decon22 = Conv2D(256,(3,3),strides=(1,1),padding = 'same',kernel_initializer = 'he_uniform',name='deconv21')(decon21)
    decon23 = BatchNormalization(axis = 3, freeze = True,name = 'bnde21')(decon22)
    decon24 = Activation('relu')(decon23)
    decon25 = Conv2D(256,(3,3),strides=(1,1),padding = 'same',kernel_initializer = 'he_uniform',name='deconv22')(decon24)
    decon26 = BatchNormalization(axis = 3, freeze = True,name = 'bnde22')(decon25)
    decon27 = Activation('relu')(decon26)
    decon2_output =Conv2DTranspose(256,(3,3),padding='same',strides=(2,2),kernel_initializer='he_uniform')(decon27)
    #decon28 = UpSampling2D(size=(2,2))(decon27)
    #decon2_output = Conv2DTranspose(256,(3,3),padding='same',strides=(1,1),kernel_initializer='he_uniform')(decon28)
    
    decon31 = Concatenate()([D3_output,decon2_output])
    decon32 = Conv2D(256,(3,3),strides=(1,1),padding = 'same',kernel_initializer = 'he_uniform',name='deconv31')(decon31)
    decon33 = BatchNormalization(axis = 3,freeze = True, name = 'bnde31')(decon32)
    decon34 = Activation('relu')(decon33)
    decon35 = Conv2D(256,(3,3),strides=(1,1),padding = 'same',kernel_initializer = 'he_uniform',name='deconv32')(decon34)
    decon36 = BatchNormalization(axis = 3,freeze = True, name = 'bnde32')(decon35)
    decon37 = Activation('relu')(decon36)
    decon3_output = Conv2DTranspose(256,(3,3),padding='same',strides=(2,2),kernel_initializer='he_uniform')(decon37)
    #decon38 = UpSampling2D(size=(2,2))(decon37)
    #decon3_output = Conv2DTranspose(256,(3,3),padding='same',strides=(1,1),kernel_initializer='he_uniform')(decon38)
    
    decon41 = Conv2D(256,(3,3),strides=(1,1),padding = 'same',kernel_initializer = 'he_uniform',name='deconv41')(decon3_output)
    decon42 = BatchNormalization(axis = 3,freeze = True, name = 'bnde41')(decon41)
    decon43 = Activation('relu')(decon42)
    decon44 = Conv2D(256,(3,3),strides=(1,1),padding = 'same',kernel_initializer = 'he_uniform',name='deconv42')(decon43)
    decon45 = BatchNormalization(axis = 3,freeze = True, name = 'bnde42')(decon44)
    decon4_output = Activation('relu')(decon45)
    
    decon5_output = Conv2D(1,(1,1),strides=(1,1),activation = 'linear',padding = 'same',kernel_initializer = 'he_uniform',name='decon52')(decon4_output)
    #decon52 = Flatten()(decon51)
    #decon5_output = Lambda(lambda x: x*255)(decon51)
    
    layers = decon5_output
    
    model = Model(inputs,layers,name = "ODModel")
    #print(model.get_weights())
    #model.load_weights(weights_path,by_name=True)
    #print(model.get_weights())
    
    print(model.summary())
    return model

# %%
odmodel = ODmodel2()
# Out:
# /home/sumeet/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/saving.py:270: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# padding_conv1 (ZeroPadding2D)   (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9408        padding_conv1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2b (ZeroPadding (None, 58, 58, 64)   0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36864       padding2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_relu (Activation (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16384       res2a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16384       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a (Add)                     (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, 56, 56, 256)  0           res2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16384       res2a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_relu (Activation (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2b_branch2b (ZeroPadding (None, 58, 58, 64)   0           res2b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36864       padding2b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_relu (Activation (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16384       res2b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# res2b (Add)                     (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_relu (Activation)         (None, 56, 56, 256)  0           res2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16384       res2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_relu (Activation (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2c_branch2b (ZeroPadding (None, 58, 58, 64)   0           res2c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36864       padding2c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_relu (Activation (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16384       res2c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c (Add)                     (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  res2b_relu[0][0]
# __________________________________________________________________________________________________
# res2c_relu (Activation)         (None, 56, 56, 256)  0           res2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32768       res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2b (ZeroPadding (None, 30, 30, 128)  0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147456      padding3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_relu (Activation (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  65536       res3a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131072      res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a (Add)                     (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, 28, 28, 512)  0           res3a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65536       res3a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_relu (Activation (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3b_branch2b (ZeroPadding (None, 30, 30, 128)  0           res3b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147456      padding3b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_relu (Activation (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  65536       res3b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b (Add)                     (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b_relu (Activation)         (None, 28, 28, 512)  0           res3b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65536       res3b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_relu (Activation (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3c_branch2b (ZeroPadding (None, 30, 30, 128)  0           res3c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147456      padding3c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_relu (Activation (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  65536       res3c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# res3c (Add)                     (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  res3b_relu[0][0]
# __________________________________________________________________________________________________
# res3c_relu (Activation)         (None, 28, 28, 512)  0           res3c[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65536       res3c_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_relu (Activation (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3d_branch2b (ZeroPadding (None, 30, 30, 128)  0           res3d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147456      padding3d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_relu (Activation (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  65536       res3d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# res3d (Add)                     (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  res3c_relu[0][0]
# __________________________________________________________________________________________________
# res3d_relu (Activation)         (None, 28, 28, 512)  0           res3d[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131072      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2b (ZeroPadding (None, 16, 16, 256)  0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  589824      padding4a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_relu (Activation (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 262144      res4a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 524288      res3d_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a (Add)                     (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, 14, 14, 1024) 0           res4a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262144      res4a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_relu (Activation (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4b_branch2b (ZeroPadding (None, 16, 16, 256)  0           res4b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  589824      padding4b_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_relu (Activation (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 262144      res4b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b (Add)                     (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b_relu (Activation)         (None, 14, 14, 1024) 0           res4b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262144      res4b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_relu (Activation (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4c_branch2b (ZeroPadding (None, 16, 16, 256)  0           res4c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  589824      padding4c_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_relu (Activation (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 262144      res4c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# res4c (Add)                     (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  res4b_relu[0][0]
# __________________________________________________________________________________________________
# res4c_relu (Activation)         (None, 14, 14, 1024) 0           res4c[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262144      res4c_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_relu (Activation (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4d_branch2b (ZeroPadding (None, 16, 16, 256)  0           res4d_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  589824      padding4d_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b_relu (Activation (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 262144      res4d_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# res4d (Add)                     (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  res4c_relu[0][0]
# __________________________________________________________________________________________________
# res4d_relu (Activation)         (None, 14, 14, 1024) 0           res4d[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262144      res4d_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a_relu (Activation (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4e_branch2b (ZeroPadding (None, 16, 16, 256)  0           res4e_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  589824      padding4e_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b_relu (Activation (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 262144      res4e_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# res4e (Add)                     (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  res4d_relu[0][0]
# __________________________________________________________________________________________________
# res4e_relu (Activation)         (None, 14, 14, 1024) 0           res4e[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262144      res4e_relu[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a_relu (Activation (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4f_branch2b (ZeroPadding (None, 16, 16, 256)  0           res4f_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  589824      padding4f_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b_relu (Activation (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 262144      res4f_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# BABLUBABLU (Conv2D)             (None, 14, 14, 256)  262400      res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 28, 28, 256)  0           BABLUBABLU[0][0]
# __________________________________________________________________________________________________
# BABLUBABLU2 (Conv2D)            (None, 28, 28, 256)  131328      bn3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 256)  0           up_sampling2d_4[0][0]
#                                                                  BABLUBABLU2[0][0]
# __________________________________________________________________________________________________
# BABLUBABLU3 (Conv2D)            (None, 28, 28, 256)  590080      add_4[0][0]
# __________________________________________________________________________________________________
# convD11 (Conv2D)                (None, 28, 28, 256)  590080      BABLUBABLU3[0][0]
# __________________________________________________________________________________________________
# bnD11 (BatchNormalization)      (None, 28, 28, 256)  1024        convD11[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           bnD11[0][0]
# __________________________________________________________________________________________________
# convD12 (Conv2D)                (None, 28, 28, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# bnD12 (BatchNormalization)      (None, 28, 28, 256)  1024        convD12[0][0]
# __________________________________________________________________________________________________
# BABLUBABLU1 (Conv2D)            (None, 14, 14, 256)  590080      BABLUBABLU[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 56, 56, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# BABLUBABLU4 (Conv2D)            (None, 56, 56, 256)  65792       res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 256)  0           bnD12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 28, 28, 512)  1180160     BABLUBABLU1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 56, 56, 256)  0           up_sampling2d_5[0][0]
#                                                                  BABLUBABLU4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 28, 28, 768)  0           activation_16[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# BABLUBABLU5 (Conv2D)            (None, 56, 56, 256)  590080      add_5[0][0]
# __________________________________________________________________________________________________
# deconv11 (Conv2D)               (None, 28, 28, 256)  1769728     concatenate_4[0][0]
# __________________________________________________________________________________________________
# convD21 (Conv2D)                (None, 56, 56, 128)  295040      BABLUBABLU5[0][0]
# __________________________________________________________________________________________________
# bnde11 (BatchNormalization)     (None, 28, 28, 256)  1024        deconv11[0][0]
# __________________________________________________________________________________________________
# bnD21 (BatchNormalization)      (None, 56, 56, 128)  512         convD21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 256)  0           bnde11[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 56, 56, 128)  0           bnD21[0][0]
# __________________________________________________________________________________________________
# deconv12 (Conv2D)               (None, 28, 28, 256)  590080      activation_21[0][0]
# __________________________________________________________________________________________________
# convD22 (Conv2D)                (None, 56, 56, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bnde12 (BatchNormalization)     (None, 28, 28, 256)  1024        deconv12[0][0]
# __________________________________________________________________________________________________
# bnD22 (BatchNormalization)      (None, 56, 56, 128)  512         convD22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 256)  0           bnde12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 112, 112, 256 0           add_5[0][0]
# __________________________________________________________________________________________________
# BABLUBABLU6 (Conv2D)            (None, 112, 112, 256 16640       conv1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 128)  0           bnD22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 56, 56, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 112, 112, 256 0           up_sampling2d_6[0][0]
#                                                                  BABLUBABLU6[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 384)  0           activation_18[0][0]
#                                                                  conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# BABLUBABLU7 (Conv2D)            (None, 112, 112, 256 590080      add_6[0][0]
# __________________________________________________________________________________________________
# deconv21 (Conv2D)               (None, 56, 56, 256)  884992      concatenate_5[0][0]
# __________________________________________________________________________________________________
# convD31 (Conv2D)                (None, 112, 112, 64) 147520      BABLUBABLU7[0][0]
# __________________________________________________________________________________________________
# bnde21 (BatchNormalization)     (None, 56, 56, 256)  1024        deconv21[0][0]
# __________________________________________________________________________________________________
# bnD31 (BatchNormalization)      (None, 112, 112, 64) 256         convD31[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 56, 56, 256)  0           bnde21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 112, 112, 64) 0           bnD31[0][0]
# __________________________________________________________________________________________________
# deconv22 (Conv2D)               (None, 56, 56, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# convD32 (Conv2D)                (None, 112, 112, 64) 36928       activation_19[0][0]
# __________________________________________________________________________________________________
# bnde22 (BatchNormalization)     (None, 56, 56, 256)  1024        deconv22[0][0]
# __________________________________________________________________________________________________
# bnD32 (BatchNormalization)      (None, 112, 112, 64) 256         convD32[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 56, 56, 256)  0           bnde22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 112, 112, 64) 0           bnD32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 112, 112, 256 590080      activation_24[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 112, 112, 320 0           activation_20[0][0]
#                                                                  conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# deconv31 (Conv2D)               (None, 112, 112, 256 737536      concatenate_6[0][0]
# __________________________________________________________________________________________________
# bnde31 (BatchNormalization)     (None, 112, 112, 256 1024        deconv31[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 112, 112, 256 0           bnde31[0][0]
# __________________________________________________________________________________________________
# deconv32 (Conv2D)               (None, 112, 112, 256 590080      activation_25[0][0]
# __________________________________________________________________________________________________
# bnde32 (BatchNormalization)     (None, 112, 112, 256 1024        deconv32[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 112, 112, 256 0           bnde32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 224, 224, 256 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# deconv41 (Conv2D)               (None, 224, 224, 256 590080      conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# bnde41 (BatchNormalization)     (None, 224, 224, 256 1024        deconv41[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 224, 224, 256 0           bnde41[0][0]
# __________________________________________________________________________________________________
# deconv42 (Conv2D)               (None, 224, 224, 256 590080      activation_27[0][0]
# __________________________________________________________________________________________________
# bnde42 (BatchNormalization)     (None, 224, 224, 256 1024        deconv42[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 224, 224, 256 0           bnde42[0][0]
# __________________________________________________________________________________________________
# decon52 (Conv2D)                (None, 224, 224, 1)  257         activation_28[0][0]
# ==================================================================================================
# Total params: 22,518,593
# Trainable params: 13,937,025
# Non-trainable params: 8,581,568
# __________________________________________________________________________________________________
# None

# %%
imgs_gt =[]
imgs_o = []
count_gt = 0
count_o = 0
for j in range(10):
    #print(j + 1)
    img_cnt = str(j + 1)
    img_path_gt = 'Images_for_FCRN/New/img' + img_cnt + '/gt'
    img_path_o = 'Images_for_FCRN/New/img' + img_cnt + '/o'
    for i in range((len(os.listdir(img_path_gt)))):
        cnt = str(i + 1)
        path_gt = img_path_gt + '/img' + img_cnt + '_' + cnt + 'gt.jpg'
        img_gt = cv2.imread(path_gt)
        img_gt = cv2.cvtColor(img_gt,cv2.COLOR_RGB2GRAY)
        if img_gt.shape == (224,224):
            imgs_gt.append(img_gt)
            count_gt = count_gt + 1
            #added for aug
            rotated = imutils.rotate(img_gt,45)
            imgs_gt.append(rotated)
            rotated = imutils.rotate(img_gt,80)
            imgs_gt.append(rotated)
            rotated = imutils.rotate(img_gt,135)
            imgs_gt.append(rotated)
            rotated = imutils.rotate(img_gt,160)
            imgs_gt.append(rotated)
            count_gt = count_gt + 4
        path_o = img_path_o + '/img' + img_cnt + '_' + cnt + 'o.jpg'
        img_o = cv2.imread(path_o)
        img_o = cv2.cvtColor(img_o, cv2.COLOR_BGR2RGB)
        if img_o.shape == (224,224,3):
            imgs_o.append(img_o)
            count_o = count_o + 1
            rotated = imutils.rotate(img_o,45)
            imgs_o.append(rotated)
            rotated = imutils.rotate(img_o,80)
            imgs_o.append(rotated)
            rotated = imutils.rotate(img_o,135)
            imgs_o.append(rotated)
            rotated = imutils.rotate(img_o,160)
            imgs_o.append(rotated)
            count_o = count_o + 4

print(count_o)
print(count_gt)
# Out:
# 18480
# 18480

# %%
'''
for i in range(1,501):
    img_cnt = str(i)
    image_o = cv2.imread('Images_for_FCRN/Black/o/img_' + img_cnt + 'o.jpg')
    image_o = cv2.cvtColor(image_o, cv2.COLOR_BGR2RGB)
    imgs_o.append(image_o)
    image_gt = cv2.imread('Images_for_FCRN/Black/gt/img_' + img_cnt + 'gt.jpg')
    image_gt = cv2.cvtColor(image_gt,cv2.COLOR_RGB2GRAY)
    imgs_gt.append(image_gt)
    count_gt = count_gt + 1
    count_o = count_o + 1
print(count_gt,' ',count_o)
'''
imgs_gt = np.asarray(imgs_gt)
imgs_gt = imgs_gt.reshape((18480,224,224,1))
imgs_o = np.asarray(imgs_o)
print(imgs_gt.shape)
print(imgs_o.shape)
# Out:
# (18480, 224, 224, 1)
# (18480, 224, 224, 3)

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=0,
    width_shift_range=0,
    height_shift_range=0,
    horizontal_flip=False)

datagen.fit(imgs_o)

# %%
print(np.amax(imgs_o))
# Out:
# 255

# %%
class LossHistory(Callback):
    def on_train_begin(self,logs={}):
        self.losses=[]
        self.lr = []
        
    def on_epoch_end(self,batch,logs={}):
        self.losses.append(logs.get('loss'))
        self.lr.append(exp_decay(len(self.losses)))

def exp_decay(epoch):
    initial_lrate = 0.001
    k = 0.1
    lrate = initial_lrate * exp(-k*epoch)
    return lrate

lrate = LearningRateScheduler(exp_decay)

class PlotLearning(Callback):
    def on_train_begin(self, logs={}):
        self.i = 0
        self.x = []
        self.losses = []
        self.val_losses = []
        self.acc = []
        self.val_acc = []
        self.fig = plt.figure()
        
        self.logs = []

    def on_epoch_end(self, epoch, logs={}):
        
        self.logs.append(logs)
        self.x.append(self.i)
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        self.acc.append(logs.get('acc'))
        self.val_acc.append(logs.get('val_acc'))
        self.i += 1
        f, (ax1, ax2) = plt.subplots(1, 2, sharex=True)
        
        clear_output(wait=True)
        
        ax1.set_yscale('log')
        ax1.plot(self.x, self.losses, label="loss")
        ax1.plot(self.x, self.val_losses, label="val_loss")
        ax1.legend()
        
        ax2.plot(self.x, self.acc, label="accuracy")
        ax2.plot(self.x, self.val_acc, label="validation accuracy")
        ax2.legend()
        
        plt.show();
        
plot = PlotLearning()

loss_history = LossHistory()
callbacks_list = [loss_history,plot,ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.h5', monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=40)]
#callbacks_list = [loss_history,plot,ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.h5', monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=50)]

# %%
def huber_loss(y_true, y_pred, clip_delta=200.0):
    error = y_true - y_pred
    cond  = tf.keras.backend.abs(error) < clip_delta

    squared_loss = 0.5 * tf.keras.backend.square(error)
    linear_loss  = clip_delta * (tf.keras.backend.abs(error) - 0.5 * clip_delta)

    return tf.where(cond, squared_loss, linear_loss)

# %%
lr_rate = 0.01
decay_rate = lr_rate/10;

#my_optimizer = SGD(lr=0.01, decay=lr_rate/200, momentum=10, nesterov=True)
my_optimizer = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=decay_rate, amsgrad=False)
#my_optimizer = RMSprop(lr = 0.001,epsilon=None,decay = 0.0)
odmodel.compile(optimizer=my_optimizer, loss='mean_squared_error',metrics = ["accuracy"])
#odmodel.compile(optimizer=my_optimizer, loss=huber_loss,metrics = ["accuracy"])

# %%
odmodel.fit(imgs_o[0:500],imgs_gt[0:500],validation_split = 0.2,epochs=200,callbacks=callbacks_list,batch_size=8)
#odmodel.save('vgg19_aug_inverter_on_all_imagesx6.h5')
# Out:
# Epoch 39/200
# 232/400 [================>.............] - ETA: 10s - loss: 107.3165 - acc: 0.1344
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-8f88ab5121a1> in <module>()
# ----> 1 odmodel.fit(imgs_o[0:500],imgs_gt[0:500],validation_split = 0.2,epochs=200,callbacks=callbacks_list,batch_size=8)
#       2 #odmodel.save('vgg19_aug_inverter_on_all_imagesx6.h5')
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2593             raise TypeError('`inputs` should be a list or tuple.')
#    2594
# -> 2595         session = get_session()
#    2596         feed_arrays = []
#    2597         array_vals = []
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     188             candidate_vars = []
#     189             for v in variables:
# --> 190                 if not getattr(v, '_keras_initialized', False):
#     191                     candidate_vars.append(v)
#     192             if candidate_vars:
#
# KeyboardInterrupt:

# %%
odmodel.save('fpn_clip_400.h5')

# %%
model=load_model('fpn_clip_400.h5',custom_objects={'huber_loss':huber_loss})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-6f0b5c947bec> in <module>()
# ----> 1 model=load_model('fpn_clip_400.h5',custom_objects={'huber_loss':huber_loss})
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     259             raise ValueError('No model found in config file.')
#     260         model_config = json.loads(model_config.decode('utf-8'))
# --> 261         model = model_from_config(model_config, custom_objects=custom_objects)
#     262
#     263         # set weights
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/saving.py in model_from_config(config, custom_objects)
#     333                         '`Sequential.from_config(config)`?')
#     334     from ..layers import deserialize
# --> 335     return deserialize(config, custom_objects=custom_objects)
#     336
#     337
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#      53                                     module_objects=globs,
#      54                                     custom_objects=custom_objects,
# ---> 55                                     printable_module_name='layer')
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     143                     config['config'],
#     144                     custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 145                                         list(custom_objects.items())))
#     146             with CustomObjectScope(custom_objects):
#     147                 return cls.from_config(config['config'])
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/network.py in from_config(cls, config, custom_objects)
#    1034         # First, we create all layers and enqueue nodes to be processed
#    1035         for layer_data in config['layers']:
# -> 1036             process_layer(layer_data)
#    1037         # Then we process nodes in order of layer depth.
#    1038         # Nodes that cannot yet be processed (if the inbound node
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/network.py in process_layer(layer_data)
#    1020
#    1021             layer = deserialize_layer(layer_data,
# -> 1022                                       custom_objects=custom_objects)
#    1023             created_layers[layer_name] = layer
#    1024
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#      53                                     module_objects=globs,
#      54                                     custom_objects=custom_objects,
# ---> 55                                     printable_module_name='layer')
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     145                                         list(custom_objects.items())))
#     146             with CustomObjectScope(custom_objects):
# --> 147                 return cls.from_config(config['config'])
#     148         else:
#     149             # Then `cls` may be a function returning a class.
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/base_layer.py in from_config(cls, config)
#    1122             A layer instance.
#    1123         """
# -> 1124         return cls(**config)
#    1125
#    1126     def count_params(self):
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/layers/normalization.py in __init__(self, axis, momentum, epsilon, center, scale, beta_initializer, gamma_initializer, moving_mean_initializer, moving_variance_initializer, beta_regularizer, gamma_regularizer, beta_constraint, gamma_constraint, **kwargs)
#      73                  gamma_constraint=None,
#      74                  **kwargs):
# ---> 75         super(BatchNormalization, self).__init__(**kwargs)
#      76         self.supports_masking = True
#      77         self.axis = axis
#
# ~/.virtualenvs/dl4cv/lib/python3.5/site-packages/keras/engine/base_layer.py in __init__(self, **kwargs)
#     126         for kwarg in kwargs:
#     127             if kwarg not in allowed_kwargs:
# --> 128                 raise TypeError('Keyword argument not understood:', kwarg)
#     129         name = kwargs.get('name')
#     130         if not name:
#
# TypeError: ('Keyword argument not understood:', 'freeze')
